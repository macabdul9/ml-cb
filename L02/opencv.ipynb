# %%
import cv2

# %%
# opencv reads bgr format
img = cv2.imread("cat.jpeg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));

# %%
img.shape
# Out:
# (331, 500, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
img.shape
# Out:
# (331, 500)

# %%
plt.imshow(img[...,[2, 1, 0]])

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img);

# %%
img.shape
# Out:
# (331, 500)

# %%
img.shape
# Out:
# (331, 500)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img)
# Out:
# [[17 24 31 ...  6  6  6]
#  [15 21 28 ...  6  6  6]
#  [12 19 26 ...  6  6  6]
#  ...
#  [10  7  4 ...  0  0  0]
#  [10  7  4 ...  0  0  0]
#  [11  8  4 ...  0  0  0]]
